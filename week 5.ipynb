# %%
if num = 5

if num > 0:
    print(num, "is a positive number.")
else:
    if num < 0:
        print(num, "is a negative number.")
    else:
        print(num, "is zero.")
# Out:
# 5 is a positive number.

# %%
age = 143

if age >= 60:
    print("You are an artefact")
else:
    if age >= 18:
        print("You are an adult")
    else:
        print("You are a child")
# Out:
# You are an artefact

# %%
def login():
  username = input("Username: ")
  password = input("Password: ")
  if username == "user" and password == "pass":
    print("Login successful!")
  else:
    print("Login failed.")

login()
# Out:
# Username: admin
# Password: password
# Login failed.

# %%
if login():
  username = input("Masukkan username: ")
  password = input("Masukkan password: ")

  if username == "admin" and password == "password":
    print("Anda berhasil login sebagai admin.")
  elif username == "admin" and password == "12345":
    print("Password terlalu lemah. Silahkan ubah password Anda.")
  elif username == "guest" and password == "guest":
    print("Anda berhasil login sebagai guest.")
  elif username == "guest" and password != "guest":
    print("Password salah.")
  else:
    print("User tidak ditemukan.")

login()
# Out:
# Masukkan username: guest
# Masukkan password: guest
# Anda berhasil login sebagai guest.
# Masukkan username: Daffa
# Masukkan password: 12345
# User tidak ditemukan.

# %%
def age():
  age = int(input("Masukkan umur Anda: "))

  if age >= 60:
    print("You are an artefact")
  elif age >= 18:
    print("You are an adult")
  else:
    print("You are a child")
age()
# Out:
# Masukkan umur Anda: 14
# You are a child

# %%
tahun = int(input("Masukkan tahun: "))

if (tahun % 4 == 0):
   if (tahun % 100 ==0):
      if (tahun % 400 == 0):
         print(f"Tahun {tahun} adalah tahun kabisat.")
      else:
         print(f"Tahun {tahun} bukan tahun kabisat.")
   else:
      print(f"Tahun {tahun} adalah tahun kabisat.")
else:
   print(f"Tahun {tahun} bukan tahun kabisat.")
# Out:
# Masukkan tahun: 2024
# Tahun 2024 adalah tahun kabisat.

# %%
tahun = int(input("Masukkan tahun: "))

if (tahun % 4 == 0):
   if (tahun % 100 ==0):
      if (tahun % 400 == 0):
         print(f"Tahun {tahun} adalah tahun kabisat.")
      else:
         print(f"Tahun {tahun} bukan tahun kabisat.")
   else:
      print(f"Tahun {tahun} adalah tahun kabisat.")
else:
   print(f"Tahun {tahun} bukan tahun kabisat.")
# Out:
# Masukkan tahun: 2024
# Tahun 2024 adalah tahun kabisat.

# %%
print ("Mencari nilai terbesar dari 3 angka")

num1 = float(input("Masukkan angka pertama: "))
num2 = float(input("Masukkan angka kedua: "))
num3 = float(input("Masukkan angka ketiga: "))

if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3

print(f"Angka pertama adalah  : {num1}")
print(f"Angka kedua adalah    : {num2}")
print(f"Angka ketiga adalah   : {num3}\n")
print(f"Angka terbesar adalah : {largest}\n")
# Out:
# Mencari nilai terbesar dari 3 angka
# Masukkan angka pertama: 60
# Masukkan angka kedua: 200
# Masukkan angka ketiga: 5
# Angka pertama adalah  : 60.0
# Angka kedua adalah    : 200.0
# Angka ketiga adalah   : 5.0
#
# Angka terbesar adalah : 200.0

# %%
Category = input ("Member/bukan : ")
total_belanja = int(input("Total belanja : "))

if total_belanja > 200000:
   diskon = 4
elif total_belanja > 100000:
   diskon = 3

if Category == "Member":
   diskon += 2

diskon_total = (diskon / 100) * total_belanja
total = total_belanja - diskon_total

print(f"Total purchases   : ${total_belanja}")
print(f"Persenan diskon   : ${diskon}  ")
print(f"Total diskon      : ${diskon_total}")
print(f"Jumlah Pembayaran : ${total}")
# Out:
# Member/bukan : Member
# Total belanja : 250000
# Total purchases   : $250000
# Persenan diskon   : $6
# Total diskon      : $15000.0
# Jumlah Pembayaran : $235000.0

# %%
print("Guten nacht! new user")
username = input("Masukkan nama: ")
email = input("Masukkan email:")
password = input("Masukkan password:")

if not username:
  print("Gak baca kah ajg, suruh masukin nama, lu buta apa idiot?")
elif "@" not in email:
  print("you forgot the (@) fool")
elif len(password) < 8:
  print("Error, minimal 8 karakter")
else:
  print("Yayyyyyy")
# Out:
# Guten nacht! new user
# Masukkan nama:
# Masukkan email:alocjamsut@gmail.com
# Masukkan password:111111111111
# Gak baca kah ajg, suruh masukin nama, lu buta apa idiot?

# %%
print("Guten nacht! new user")
username = input("Masukkan nama: ")
email = input("Masukkan email:")
password = input("Masukkan password:")

if not username:
  print("Gak baca kah ajg, suruh isi nama, lu buta apa idiot?")
elif "@" not in email:
  print("Errorrrrr 10101010101010101010010101")
elif len(password) < 8:
  print("Error, minimal 8 karakter")
else:
  print("Yayyyyyy")
# Out:
# Guten nacht! new user
# Masukkan nama: drake
# Masukkan email:gigachad.gmail.id
# Masukkan password:lapannnnn
# Errorrrrr 10101010101010101010010101

# %%
print("Guten nacht! new user")
username = input("Masukkan nama: ")
email = input("Masukkan email:")
password = input("Masukkan password:")

if not username:
  print("Gak baca kah ajg, lu buta apa idiot?")
elif "@" not in email:
  print("Error, use (@) idiot!")
elif len(password) < 8:
  print("Error, minimal 8 karakter")
else:
  print("Yayyyyyy")
# Out:
# Guten nacht! new user
# Masukkan nama: nama
# Masukkan email:email@gmail.com
# Masukkan password:password
# Yayyyyyy

# %%
print("Guten nacht! new user")
username = input("Masukkan nama: ")
email = input("Masukkan email")
password = input("Masukkan password")

if not username:
  print("Gak baca kah ajg, lu buta apa idiot?")
elif "@" not in email:
  print("Errorrrrr 10101010101010101010010101")
elif len(password) < 8:
  print("Error, minimal 8 karakter")
else:
  print("Yayyyyyy")
# Out:
# Guten nacht! new user
# Masukkan nama: daodjaod
# Masukkan emailifiafjijsfi@gmail.com
# Masukkan passwordfofjfo
# Error, minimal 8 karakter

# %%
print("Guten nacht! new user")
username = input("Masukkan nama: ")
email = input("Masukkan email")
password = input("Masukkan password")

if not username:
  print("Gak baca kah ajg, lu buta apa idiot?")
elif "@" not in email:
  print("Errorrrrr 10101010101010101010010101")
elif len(password) < 8:
  print("Error, minimal 8 karakter")
else:
  print("Yayyyyyy")
# Out:
# Guten nacht! new user
# Masukkan nama: Daffasigma@gmail.com
# Masukkan emailpalepale@gmail,com
# Masukkan passworddaffaireng123
# Yayyyyyy
