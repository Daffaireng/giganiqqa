# %%
"ACDC" != "AXEL ROSE"
# Out:
# True

# %%
umur = int(input("Masukkan umur Anda: "))

if umur >= 17:
    print("Boleh membuat SIM")
else:
    print("Tidak boleh mmebuat SIM.")
# Out:
# Masukkan umur Anda: 77
# Boleh membuat SIM

# %%
Nilai = int(input("Nilai : "))
if Nilai >= 90 :
  print("A")
elif Nilai >= 80 :
  print("B+")
elif Nilai >= 70 :
  print("B")
elif Nilai >= 60 :
  print("C+")
elif Nilai >= 50 :
  print("C")
elif Nilai >= 40 :
  print("D")
elif Nilai < 40 :
  print("E")
else:
  print("Tidak ada")
# Out:
# Nilai : 96
# A

# %%
nilai = float(input("Masukkan nilai Anda: "))

if nilai >= 80:
    grade = "A"
elif nilai >= 77.5:
    grade = "A-"
elif nilai >= 75:
    grade = "A/B"
elif nilai >= 72.5:
    grade = "B+"
elif nilai >= 70:
    grade = "B"
elif nilai >= 67.5:
    grade = "B-"
elif nilai >= 65:
    grade = "B/C"
elif nilai >= 62.5:
    grade = "C+"
elif nilai >= 60:
    grade = "C"
elif nilai >= 55:
    grade = "C-"
elif nilai >= 50:
    grade = "C/D"
elif nilai >= 45:
    grade = "D+"
elif nilai >= 40:
    grade = "D"
else:
    grade = "E"

print("Nilai huruf Anda adalah:", grade)
# Out:
# Masukkan nilai Anda: 40
# Nilai huruf Anda adalah: D

# %%
Nilai = float(input("Nilai : "))
if 99 <= Nilai <= 100 :
  print("A+")
elif 97 <= Nilai <= 98 :
  print("A")
elif 95 <= Nilai <= 96 :
  print("A-")
elif 93 <= Nilai <= 94 :
  print("B+")
elif 91 <= Nilai <= 92 :
  print("B")
elif 89 <= Nilai <= 90 :
  print("B-")
elif 85 <= Nilai <= 88 :
  print("C+")
elif 82 <= Nilai <= 84 :
  print("C")
elif 79 <= Nilai <= 81 :
  print("C-")
elif 77 <= Nilai <= 78 :
  print("D+")
elif 75 <= Nilai <= 76 :
  print("D")
elif Nilai < 75 :
  print("E")
else:
  print("Tidak ada")
# Out:
# Nilai : 100
# A+

# %%
if usia>= 1100:
  print("Artefak")
